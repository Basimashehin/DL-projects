# %% [markdown]
# <a href="https://colab.research.google.com/github/Basimashehin/DL-projects/blob/master/yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/pjreddie/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
cd darknet
# Out:
# /content/darknet

# %%
ls
# Out:
# backup/   data/      libdarknet.a    LICENSE.fuck  LICENSE.meta  Makefile  README.md  src/
# cfg/      examples/  libdarknet.so*  LICENSE.gen   LICENSE.mit   obj/      results/
# darknet*  include/   LICENSE         LICENSE.gpl   LICENSE.v1    python/   scripts/

# %%
# !make
# Out:
# make: Nothing to be done for 'all'.

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2023-12-11 19:32:52--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  19.4MB/s    in 12s
#
# 2023-12-11 19:33:05 (19.2 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !./darknet detect /content/darknet/cfg/yolov3.cfg /content/darknet/yolov3.weights /content/dog.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#    10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
# ...

# %%
# !./darknet detect /content/darknet/cfg/yolov3.cfg /content/darknet/yolov3.weights /content/download.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#    10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/darknet/predictions.jpg')
img=cv2.resize(img,(300,300))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
